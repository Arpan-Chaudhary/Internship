# %%
# first we import numpy and pandas for reading the dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
# ...

# %%
# after reading the dataset, check the datatype, in which form data exists

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
# some data are present as int, some in object form

# %%
# let's check for null values

# %%
df.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
# in one column, null values are present

# %%
# we will check null values and datatype individually for all columns

# %%
# importing encoder for encoding the required column

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

lab_enc = LabelEncoder()

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# now start checking nulls individually for all columns and fill nulls wherever present
# we encode the required column also

# %%
df['Id'].unique()
# Out:
# array([127, 889, 793, ..., 196,  31, 617], dtype=int64)

# %%
df['Id'].isna().sum()
# Out:
# 0

# %%
df['MSSubClass'].unique()
# Out:
# array([120,  20,  60,  50,  70,  30, 160,  85,  45,  90,  40,  80, 190,
#         75, 180], dtype=int64)

# %%
df['MSSubClass'].isna().sum()
# Out:
# 0

# %%
df['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'FV', 'RH', 'C (all)'], dtype=object)

# %%
df['MSZoning'].isna().sum()
# Out:
# 0

# %%
df['MSZoning'] = lab_enc.fit_transform(df['MSZoning'])

# %%
df['LotFrontage'].unique()
# Out:
# array([ nan,  95.,  92., 105.,  58.,  88.,  70.,  80.,  50.,  44., 129.,
#         59.,  55.,  64.,  24.,  68.,  71.,  74.,  61.,  60., 120.,  84.,
#        141.,  30.,  65.,  76., 100.,  85.,  75., 107., 122.,  82.,  62.,
#         73.,  79.,  77.,  41.,  69.,  90.,  96.,  72.,  34.,  78.,  63.,
#         40.,  98., 160., 108., 128.,  51.,  81.,  99.,  66.,  37., 174.,
#         87.,  53., 152.,  47.,  86.,  56.,  89.,  35.,  52.,  21., 104.,
#         57.,  83.,  46., 101., 112., 149.,  93.,  49.,  43., 130.,  54.,
#         91.,  67.,  97., 110., 103., 115.,  94.,  48.,  36., 313., 109.,
#        144., 121., 102., 116., 182.,  32.,  42., 168., 118.,  38., 140.,
#        134., 114., 124.,  39., 111.,  45., 106., 153.])

# %%
df['LotFrontage'].isna().sum()
# Out:
# 214

# %%
df['LotFrontage'].mean()
# Out:
# 70.98846960167715

# %%
df['LotFrontage'] = df['LotFrontage'].replace(np.nan,70.988)

# %%
df['LotFrontage'].isna().sum()
# Out:
# 0

# %%
df['LotArea'].unique()
# Out:
# array([  4928,  15865,   9920,  11751,  16635,  14054,  11341,  13125,
#          9170,   8480,   8600,   9548,   9196,   8892,  16466,  10592,
#          5890,   7314,   7917,   2016,  12435,   8445,   9717,  10659,
#          9230,  21000,  25339,  11394,   6380,  11988,   7658,   3378,
#         18890,  12358,  14762,  10356,  10400,  12615,   7540,   9100,
#         31770,  13300,   3180,   2522,   8385,   8314,   8123,  12000,
#          5000,   7931,  14331,  10440,   8400,   8712,  11100,   9742,
#         19900,  10186,   8765,  11923,   7200,   7838,   7024,  11287,
#          8834,   5500,   9858,  32668,   8760,   8366,   9158,   6780,
#          9020,   4270,  10637,  10410,  13891,  16196,   8990,   8635,
#          9786,  10010,   7950,   6180,   8461,   7642,   9600,   9240,
#          9525,   4923,  11075,   6820,   9204,   8973,   8125,   5330,
#          5868,  11250,  22950,  11308,  10500,  13600,  10152,   4590,
# ...

# %%
df['LotArea'].isna().sum()
# Out:
# 0

# %%
df['Street'].unique()
# Out:
# array(['Pave', 'Grvl'], dtype=object)

# %%
df['Street'].isna().sum()
# Out:
# 0

# %%
df['Street'] = lab_enc.fit_transform(df['Street'])

# %%
df['Alley'].unique()
# Out:
# array([nan, 'Grvl', 'Pave'], dtype=object)

# %%
df['Alley'].isna().sum()
# Out:
# 1091

# %%
df['Alley'].mode()
# Out:
# 0    Grvl
# Name: Alley, dtype: object

# %%
df['Alley'] = df['Alley'].replace(np.nan,'Grvl')

# %%
df['Alley'].isna().sum()
# Out:
# 0

# %%
df['Alley'] = lab_enc.fit_transform(df['Alley'])

# %%
df['LotShape'].unique()
# Out:
# array(['IR1', 'Reg', 'IR2', 'IR3'], dtype=object)

# %%
df['LotShape'].isna().sum()
# Out:
# 0

# %%
df['LotShape'] = lab_enc.fit_transform(df['LotShape'])

# %%
df['LandContour'].unique()
# Out:
# array(['Lvl', 'Bnk', 'HLS', 'Low'], dtype=object)

# %%
df['LandContour'].isna().sum()
# Out:
# 0

# %%
df['LandContour'] = lab_enc.fit_transform(df['LandContour'])

# %%
df['Utilities'].unique()
# Out:
# array(['AllPub'], dtype=object)

# %%
df['Utilities'].isna().sum()
# Out:
# 0

# %%
df['Utilities'] = lab_enc.fit_transform(df['Utilities'])

# %%
df['LotConfig'].unique()
# Out:
# array(['Inside', 'CulDSac', 'FR2', 'Corner', 'FR3'], dtype=object)

# %%
df['LotConfig'].isna().sum()
# Out:
# 0

# %%
df['LotConfig'] = lab_enc.fit_transform(df['LotConfig'])

# %%
df['LandSlope'].unique()
# Out:
# array(['Gtl', 'Mod', 'Sev'], dtype=object)

# %%
df['LandSlope'].isna().sum()
# Out:
# 0

# %%
df['LandSlope'] = lab_enc.fit_transform(df['LandSlope'])

# %%
df['Neighborhood'].unique()
# Out:
# array(['NPkVill', 'NAmes', 'NoRidge', 'NWAmes', 'Gilbert', 'Sawyer',
#        'Edwards', 'IDOTRR', 'CollgCr', 'Mitchel', 'Crawfor', 'BrDale',
#        'StoneBr', 'BrkSide', 'NridgHt', 'OldTown', 'Somerst', 'Timber',
#        'SWISU', 'SawyerW', 'ClearCr', 'Veenker', 'Blmngtn', 'MeadowV',
#        'Blueste'], dtype=object)

# %%
df['Neighborhood'].isna().sum()
# Out:
# 0

# %%
df['Neighborhood'] = lab_enc.fit_transform(df['Neighborhood'])

# %%
df['Condition1'].unique()
# Out:
# array(['Norm', 'Feedr', 'RRAn', 'PosA', 'RRAe', 'Artery', 'PosN', 'RRNe',
#        'RRNn'], dtype=object)

# %%
df['Condition1'].isna().sum()
# Out:
# 0

# %%
df['Condition1'] = lab_enc.fit_transform(df['Condition1'])

# %%
df['Condition2'].unique()
# Out:
# array(['Norm', 'RRAe', 'Feedr', 'PosN', 'Artery', 'RRNn', 'PosA', 'RRAn'],
#       dtype=object)

# %%
df['Condition2'].isna().sum()
# Out:
# 0

# %%
df['Condition2'] = lab_enc.fit_transform(df['Condition2'])

# %%
df['BldgType'].unique()
# Out:
# array(['TwnhsE', '1Fam', 'Duplex', 'Twnhs', '2fmCon'], dtype=object)

# %%
df['BldgType'].isna().sum()
# Out:
# 0

# %%
df['BldgType'] = lab_enc.fit_transform(df['BldgType'])

# %%
df['HouseStyle'].unique()
# Out:
# array(['1Story', '2Story', '1.5Fin', 'SFoyer', '1.5Unf', 'SLvl', '2.5Fin',
#        '2.5Unf'], dtype=object)

# %%
df['HouseStyle'].isna().sum()
# Out:
# 0

# %%
df['HouseStyle'] = lab_enc.fit_transform(df['HouseStyle'])

# %%
df['OverallQual'].unique()
# Out:
# array([ 6,  8,  7,  5,  9,  1,  2,  4,  3, 10], dtype=int64)

# %%
df['OverallQual'].isna().sum()
# Out:
# 0

# %%
df['OverallCond'].unique()
# Out:
# array([5, 6, 7, 4, 8, 2, 3, 9, 1], dtype=int64)

# %%
df['OverallCond'].isna().sum()
# Out:
# 0

# %%
df['YearBuilt'].unique()
# Out:
# array([1976, 1970, 1996, 1977, 2006, 1957, 1965, 1947, 1937, 2003, 1960,
#        1955, 1923, 1930, 2007, 2001, 1972, 1950, 1961, 1953, 1918, 2010,
#        1922, 1934, 2005, 1946, 1941, 1948, 1975, 1978, 1956, 2004, 1982,
#        2000, 2002, 1920, 1992, 1936, 1967, 1989, 1929, 1968, 1959, 1935,
#        1966, 1931, 1916, 1998, 1962, 1974, 1926, 1904, 1995, 1969, 1985,
#        1963, 1958, 1892, 2008, 1971, 1980, 1945, 1986, 1981, 1949, 1940,
#        1954, 1925, 1915, 1921, 1924, 1999, 1951, 1993, 1964, 1900, 1919,
#        1910, 1938, 1880, 1988, 1911, 1990, 1979, 1927, 1983, 1994, 2009,
#        1928, 1917, 1898, 1997, 1984, 1973, 1952, 1939, 1987, 1890, 1942,
#        1991, 1932, 1908, 1914, 1882, 1905, 1875, 1906, 1893, 1912, 1913],
#       dtype=int64)

# %%
df['YearBuilt'].isna().sum()
# Out:
# 0

# %%
df['YearRemodAdd'].unique()
# Out:
# array([1976, 1970, 1997, 1977, 2000, 2006, 1996, 1965, 1950, 2003, 1960,
#        1955, 2007, 2001, 1961, 1998, 1953, 2010, 1995, 2005, 1992, 1975,
#        1978, 1982, 2002, 1989, 1967, 1968, 1959, 2004, 1966, 2008, 1987,
#        1981, 1969, 1985, 1963, 1991, 1993, 1971, 1990, 1956, 1986, 1999,
#        1954, 1957, 1994, 1972, 1958, 1980, 1979, 1951, 1983, 2009, 1962,
#        1964, 1952, 1984, 1988, 1974, 1973], dtype=int64)

# %%
df['YearRemodAdd'].isna().sum()
# Out:
# 0

# %%
df['RoofStyle'].unique()
# Out:
# array(['Gable', 'Flat', 'Hip', 'Shed', 'Gambrel', 'Mansard'], dtype=object)

# %%
df['RoofStyle'].isna().sum()
# Out:
# 0

# %%
df['RoofStyle'] = lab_enc.fit_transform(df['RoofStyle'])

# %%
df['RoofMatl'].unique()
# Out:
# array(['CompShg', 'Tar&Grv', 'WdShngl', 'WdShake', 'Roll', 'ClyTile',
#        'Metal', 'Membran'], dtype=object)

# %%
df['RoofMatl'].isna().sum()
# Out:
# 0

# %%
df['RoofMatl'] = lab_enc.fit_transform(df['RoofMatl'])

# %%
df['Exterior1st'].unique()
# Out:
# array(['Plywood', 'Wd Sdng', 'MetalSd', 'CemntBd', 'VinylSd', 'HdBoard',
#        'Stucco', 'WdShing', 'BrkFace', 'Stone', 'AsbShng', 'AsphShn',
#        'ImStucc', 'BrkComm'], dtype=object)

# %%
df['Exterior1st'].isna().sum()
# Out:
# 0

# %%
df['Exterior1st'] = lab_enc.fit_transform(df['Exterior1st'])

# %%
df['Exterior2nd'].unique()
# Out:
# array(['Plywood', 'Wd Sdng', 'MetalSd', 'CmentBd', 'VinylSd', 'HdBoard',
#        'Wd Shng', 'Stucco', 'ImStucc', 'Stone', 'BrkFace', 'AsbShng',
#        'Brk Cmn', 'AsphShn', 'Other'], dtype=object)

# %%
df['Exterior2nd'].isna().sum()
# Out:
# 0

# %%
df['Exterior2nd'] = lab_enc.fit_transform(df['Exterior2nd'])

# %%
df['MasVnrType'].unique()
# Out:
# array(['None', 'BrkFace', 'Stone', 'BrkCmn', nan], dtype=object)

# %%
df['MasVnrType'].isna().sum()
# Out:
# 7

# %%
df['MasVnrType'].mode()
# Out:
# 0    None
# Name: MasVnrType, dtype: object

# %%
df['MasVnrType'] = df['MasVnrType'].replace(np.nan,'None')

# %%
df['MasVnrType'].isna().sum()
# Out:
# 0

# %%
df['MasVnrType'] = lab_enc.fit_transform(df['MasVnrType'])

# %%
df['MasVnrArea'].unique()
# Out:
# array([0.000e+00, 4.800e+02, 1.260e+02, 1.800e+02, 6.700e+01, 2.230e+02,
#        6.600e+01, 8.200e+01, 1.740e+02, 3.040e+02, 1.720e+02, 1.660e+02,
#        1.840e+02, 3.500e+02, 4.120e+02, 1.000e+00, 1.890e+02, 1.120e+02,
#        5.000e+01, 2.200e+02, 1.600e+01, 6.300e+02, 2.810e+02, 2.870e+02,
#        3.400e+02, 2.160e+02,       nan, 1.400e+02, 1.830e+02, 3.360e+02,
#        3.960e+02, 2.320e+02, 3.200e+02, 8.500e+01, 1.620e+02, 1.540e+02,
#        1.760e+02, 1.200e+02, 1.080e+02, 2.520e+02, 1.300e+02, 3.510e+02,
#        5.710e+02, 5.300e+01, 2.040e+02, 9.750e+02, 6.530e+02, 8.000e+01,
#        4.720e+02, 3.400e+01, 1.650e+02, 2.370e+02, 1.130e+02, 9.000e+01,
#        1.600e+02, 1.470e+02, 1.360e+02, 3.760e+02, 8.900e+01, 4.150e+02,
#        2.000e+02, 5.060e+02, 2.860e+02, 4.500e+01, 2.450e+02, 2.470e+02,
#        2.400e+02, 7.000e+01, 9.800e+01, 6.040e+02, 8.600e+02, 2.700e+01,
#        1.530e+02, 2.120e+02, 2.060e+02, 7.600e+02, 2.960e+02, 5.280e+02,
# ...

# %%
df['MasVnrArea'].isna().sum()
# Out:
# 7

# %%
df['MasVnrArea'].mode()
# Out:
# 0    0.0
# Name: MasVnrArea, dtype: float64

# %%
df['MasVnrArea'] = df['MasVnrArea'].replace(np.nan,0.0)

# %%
df['MasVnrArea'].isna().sum()
# Out:
# 0

# %%
df['ExterQual'].unique()
# Out:
# array(['TA', 'Gd', 'Ex', 'Fa'], dtype=object)

# %%
df['ExterQual'].isna().sum()
# Out:
# 0

# %%
df['ExterQual'] = lab_enc.fit_transform(df['ExterQual'])

# %%
df['ExterCond'].unique()
# Out:
# array(['TA', 'Gd', 'Fa', 'Po', 'Ex'], dtype=object)

# %%
df['ExterCond'].isna().sum()
# Out:
# 0

# %%
df['ExterCond'] = lab_enc.fit_transform(df['ExterCond'])

# %%
df['Foundation'].unique()
# Out:
# array(['CBlock', 'PConc', 'BrkTil', 'Slab', 'Stone', 'Wood'], dtype=object)

# %%
df['Foundation'].isna().sum()
# Out:
# 0

# %%
df['Foundation'] = lab_enc.fit_transform(df['Foundation'])

# %%
df['BsmtQual'].unique()
# Out:
# array(['Gd', 'TA', 'Ex', nan, 'Fa'], dtype=object)

# %%
df['BsmtQual'].isna().sum()
# Out:
# 30

# %%
df['BsmtQual'].mode()
# Out:
# 0    TA
# Name: BsmtQual, dtype: object

# %%
df['BsmtQual'] = df['BsmtQual'].replace(np.nan,'TA')

# %%
df['BsmtQual'].isna().sum()
# Out:
# 0

# %%
df['BsmtQual'] = lab_enc.fit_transform(df['BsmtQual'])

# %%
df['BsmtCond'].unique()
# Out:
# array(['TA', 'Gd', 'Fa', nan, 'Po'], dtype=object)

# %%
df['BsmtCond'].isna().sum()
# Out:
# 30

# %%
df['BsmtCond'].mode()
# Out:
# 0    TA
# Name: BsmtCond, dtype: object

# %%
df['BsmtCond'] = df['BsmtCond'].replace(np.nan,'TA')

# %%
df['BsmtCond'].isna().sum()
# Out:
# 0

# %%
df['BsmtCond'] = lab_enc.fit_transform(df['BsmtCond'])

# %%
df['BsmtExposure'].unique()
# Out:
# array(['No', 'Gd', 'Av', 'Mn', nan], dtype=object)

# %%
df['BsmtExposure'].isna().sum()
# Out:
# 31

# %%
df['BsmtExposure'].mode()
# Out:
# 0    No
# Name: BsmtExposure, dtype: object

# %%
df['BsmtExposure'] = df['BsmtExposure'].replace(np.nan,'No')

# %%
df['BsmtExposure'].isna().sum()
# Out:
# 0

# %%
df['BsmtExposure'] = lab_enc.fit_transform(df['BsmtExposure'])

# %%
df['BsmtFinType1'].unique()
# Out:
# array(['ALQ', 'GLQ', 'BLQ', 'Unf', 'Rec', 'LwQ', nan], dtype=object)

# %%
df['BsmtFinType1'].isna().sum()
# Out:
# 30

# %%
df['BsmtFinType1'].mode()
# Out:
# 0    Unf
# Name: BsmtFinType1, dtype: object

# %%
df['BsmtFinType1'] = df['BsmtFinType1'].replace(np.nan,'Unf')

# %%
df['BsmtFinType1'].isna().sum()
# Out:
# 0

# %%
df['BsmtFinType1'] = lab_enc.fit_transform(df['BsmtFinType1'])

# %%
df['BsmtFinSF1'].unique()
# Out:
# array([ 120,  351,  862,  705, 1246,    0, 1302,  168,  698,  442,  483,
#         538,  724,  751,  361,  656,   49,  915,  661,   35, 1445,  326,
#         456,  498,  360,  716,  477,  773,  639,  377,  595,  546,  144,
#         374, 1274,  493,  290,  860,  912,  674,  285,  769, 1024,  421,
#         338, 1170,  234,  510, 1219,  490,  312,  544, 1288,  116, 1386,
#        1443,  336,  600, 1071,  535,  280, 1153,  562,  368,   25,  567,
#        1196,  248,  486,  936,  432,  454,  586,   24,  375,  416,  774,
#         680,  592, 1810, 1373,  637,  196,  197,  552,   16,  904,  428,
#         189,  854, 2096,  216,  504, 1218,  978,  713,  784,   72,  795,
#         810,  633, 1148,  988,  765,  697,  733,  603,  572,  300,  180,
#         471,  450,  296,  400,  969, 1039,  767,  740,  419,  831,  689,
#         998, 1070,  427,  865,  626,  922,  388,  236,  297,  611,  228,
#        1258,  852,  522,  609,   20,  641, 1022,  250, 1106,  301,  746,
# ...

# %%
df['BsmtFinSF1'].isna().sum()
# Out:
# 0

# %%
df['BsmtFinType2'].unique()
# Out:
# array(['Unf', 'Rec', 'BLQ', 'GLQ', nan, 'ALQ', 'LwQ'], dtype=object)

# %%
df['BsmtFinType2'].isna().sum()
# Out:
# 31

# %%
df['BsmtFinType2'].mode()
# Out:
# 0    Unf
# Name: BsmtFinType2, dtype: object

# %%
df['BsmtFinType2'] = df['BsmtFinType2'].replace(np.nan,'Unf')

# %%
df['BsmtFinType2'].isna().sum()
# Out:
# 0

# %%
df['BsmtFinType2'] = lab_enc.fit_transform(df['BsmtFinType2'])

# %%
df['BsmtFinSF2'].unique()
# Out:
# array([   0,  823,  682,   96, 1029,  869,  211,  608,  532,  466,  692,
#         539,   41,  123,  193, 1120,  872,   28,  240,  239,  150,  181,
#         180,  661,  258,  486,  374,  547,   93,  230,  306,  294,  108,
#         380,   68,  396,  279,  324,  791,  479,  228,  110,  690,  290,
#         121,   40,  531,  362,   80,  634,  106,  128,  391,  336,  472,
#          35,  435,  182,  132,  495,  438,  287,   64,  168,  764, 1031,
#         210,  202, 1127,  469, 1080,  149,  670,  468,  723,  645,  411,
#         232, 1474,  177,  768,  127,  500,  620,  144,  441,   81, 1061,
#         344,  375,  219,  612,  125,  480, 1063,  906,  311,  627,  117,
#         208,  551,  147,  173,  264, 1057,  377,  630,  276,  580,  712,
#         139,  544,  606,  972,  334,   32,  163,  184,  175,  841,  400,
#         546], dtype=int64)

# %%
df['BsmtFinSF2'].isna().sum()
# Out:
# 0

# %%
df['BsmtUnfSF'].unique()
# Out:
# array([ 958, 1043,  255, 1139,  356,  879,   90,  284,  420,  390,  780,
#         458, 1560, 1065,  816,  602,  278,  508,  392,  630,  112,    0,
#         135,  203,  905,  411,  993,  389, 1296,  651,  652,  360,  253,
#        1090,  725,  115,  742,  441,  551,  600,  970,  270,  982,  172,
#         363,  526, 1017,  132, 1777, 1035,   76,  666, 1800,   95,  108,
#         386,  121,  292,  354, 1194,  798, 1496,   30,  276,  417,  660,
#         604,  690,   39, 1498,  295,  312,  195,  155,  960,  728,  912,
#         752,  650, 1055, 1099,  440,   29,  247,  413,  813,  298,  448,
#         434, 1107,  168,  432,  314,  462, 1530,  250,  409, 1290,  424,
#         104,  756,  400,   99, 1074,   32,  221,  858,  319, 1442,  844,
#         999,  342, 1550,  893,  712,  536,  884,  628, 1128,  371,  300,
#        1686,  540,  506,  163,  864,  733, 1393, 1319,  726,  586,  481,
#         264,  721,  398,  252,  180,  151, 1212,  701,  572,  765,  849,
# ...

# %%
df['BsmtUnfSF'].isna().sum()
# Out:
# 0

# %%
df['TotalBsmtSF'].unique()
# Out:
# array([1078, 2217, 1117, 1844, 1602,  879, 1392, 1134, 1214,  832,  780,
#         941, 1560, 1065,  816,  602, 1232, 1143,  630,  963,  768, 1050,
#         864, 1809, 1856,  993,  715, 1752,  651, 1361,  720,    0,  969,
#        1090, 1202,  888,  742, 1080,  928,  600,  970,  985,  982,  924,
#        1269, 1800, 1510,  290,  992, 1777, 1947,  750,  951, 1132,  807,
#         925, 1462,  926, 2035, 1194,  798, 1496,  520, 1127,  544, 1705,
#         660, 2076, 1482, 1498,  672,  912, 1389,  690,  960,  728, 1032,
#         650, 1055, 1099, 1593,  784, 1488, 1144, 1008,  813, 1494,  936,
#         920, 1107, 1104, 1048, 1554,  825, 1314, 1643, 1028,  756,  691,
#        1074, 1842, 1594,  858,  637,  319, 1442, 1040,  644, 1196,  894,
#        1574,  893, 1440,  608,  884, 1478, 1128, 1225, 2396, 1686, 1010,
#        1518, 1262,  876, 1063,  795, 1393, 1319, 1536, 1219, 1505,  721,
#        1148, 1386, 1017,  900,  848, 1337, 1212, 1304, 1486,  765,  859,
# ...

# %%
df['TotalBsmtSF'].isna().sum()
# Out:
# 0

# %%
df['Heating'].unique()
# Out:
# array(['GasA', 'GasW', 'Floor', 'OthW', 'Wall', 'Grav'], dtype=object)

# %%
df['Heating'].isna().sum()
# Out:
# 0

# %%
df['Heating'] = lab_enc.fit_transform(df['Heating'])

# %%
df['HeatingQC'].unique()
# Out:
# array(['TA', 'Ex', 'Gd', 'Fa', 'Po'], dtype=object)

# %%
df['HeatingQC'].isna().sum()
# Out:
# 0

# %%
df['HeatingQC'] = lab_enc.fit_transform(df['HeatingQC'])

# %%
df['CentralAir'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
df['CentralAir'].isna().sum()
# Out:
# 0

# %%
df['CentralAir'] = lab_enc.fit_transform(df['CentralAir'])

# %%
df['Electrical'].unique()
# Out:
# array(['SBrkr', 'FuseA', 'FuseF', 'FuseP', 'Mix'], dtype=object)

# %%
df['Electrical'].isna().sum()
# Out:
# 0

# %%
df['Electrical'] = lab_enc.fit_transform(df['Electrical'])

# %%
df['1stFlrSF'].unique()
# Out:
# array([ 958, 2217, 1127, 1844, 1602,  879, 1392, 1803, 1214,  832,  780,
#         941, 1560, 1065,  872,  900,  816, 1232, 1113,  630,  963,  768,
#        1078, 1050, 1200, 2259, 1416, 1856, 1048,  849, 1752,  707, 1361,
#         854, 1547,  969, 1370, 2158,  912,  779, 1656,  928,  520,  970,
#         985, 1007, 1122,  334, 1269, 1800, 1584,  438, 1306,  930, 1795,
#        2207, 1061,  951,  827, 1132, 1175,  925, 1462,  926,  874, 2515,
#        1194,  798, 1496, 1165,  774, 1718,  808,  803, 2076, 1494, 1498,
#        1072, 1085, 1389,  698,  986, 1040,  728, 1032, 1055, 1099, 1593,
#        1168, 1502, 2020, 1144, 1053,  822, 1652,  936,  920, 1518, 1130,
#         864, 1186, 1554, 1097, 1314,  888, 1824, 1436, 1051, 1080,  691,
#        1088, 1842, 1646,  897, 1035, 1442, 1196,  894, 1574,  901,  600,
#        1476, 1319,  884,  882, 1478, 1149, 1276, 2411, 1707,  961, 1052,
#        1262,  964,  784, 1287, 1468, 1422, 1537, 1536,  904, 1265, 1505,
# ...

# %%
df['1stFlrSF'].isna().sum()
# Out:
# 0

# %%
df['2ndFlrSF'].unique()
# Out:
# array([   0,  886,  984,  384,  596,  888,  521,  602,  672,  829,  811,
#         682, 1259,  720,  600,  739,  793, 1208,  862,  807,  762,  842,
#         704,  213,  649,  728,  514,  220,  581,  800,  843,  866, 1518,
#        1054,  896,  676,  884,  788,  439,  371,  678,  547,  900,  809,
#         677, 1151, 1141, 1336, 2065,  756,  864,  795, 1177,  981,  983,
#         595,  319,  813,  748,  622,  527, 1304, 1818, 1142,  940,  872,
#         403, 1182,  495,  913, 1020,  192, 1349,  656,  504, 1174,  539,
#         741,  623,  846,  857,  730,  924,  472,  796,  790, 1323,  685,
#        1218,  336, 1063, 1523, 1122,  871,  611, 1053,  684,  568, 1001,
#         546,  840, 1194,  628,  464,  661,  876,  742,  626,  848,  744,
#        1370,  992,  358,  883, 1101,  783,  941,  432, 1093,  709,  475,
#         378,  530,  850,  764, 1538,  325, 1112,  903,  590,  441,  806,
#         561, 1070,  928,  665,  918, 1357, 1312, 1017,  729,  780, 1040,
# ...

# %%
df['2ndFlrSF'].isna().sum()
# Out:
# 0

# %%
df['LowQualFinSF'].unique()
# Out:
# array([  0, 528,  53, 156,  80, 390, 234, 144, 572, 360, 514, 120, 384,
#        515, 481, 513, 232, 371, 473, 420, 392], dtype=int64)

# %%
df['LowQualFinSF'].isna().sum()
# Out:
# 0

# %%
df['GrLivArea'].unique()
# Out:
# array([ 958, 2217, 2013, 1844, 1602, 1863, 1392, 1803, 1214, 1216, 1376,
#        1829, 1560, 1065, 1393, 1502,  816, 1232, 1113, 1302, 1792,  768,
#        1078, 1050, 1200, 2259, 1416, 1856, 1048, 1660, 1752, 1389, 2620,
#        1382, 2320,  969, 1370, 2158,  912,  935, 1656,  928, 1709,  985,
#        1800, 1122,  334, 1269, 2792,  438, 1306,  930, 1795, 2207, 1923,
#         951,  827,  900, 1132, 1982,  925, 2224, 1316,  874, 2515, 1194,
#        1640, 1496,  754, 1165,  774, 1718,  803, 2076, 1494, 1498, 1285,
#        1734, 1426,  986, 1040, 1456, 1252, 1539, 2263, 1099, 1593, 1968,
#        2020, 1144, 1053, 1665, 1652,  936, 1786, 3608, 2184,  864, 1986,
#        1554, 1993, 1314, 1564, 1824, 1839, 1080, 1088, 1842, 1646,  872,
#        1336, 1406, 1442, 1846, 1355, 1196,  894, 1574, 1801, 1641, 2153,
#        1319, 2035,  882, 1478, 2290, 2612, 4476, 1707, 1717, 1052, 1518,
#        1262,  964, 1728,  784, 1287, 2599, 1537, 1536,  904, 1265, 1505,
# ...

# %%
df['GrLivArea'].isna().sum()
# Out:
# 0

# %%
df['BsmtFullBath'].unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
df['BsmtFullBath'].isna().sum()
# Out:
# 0

# %%
df['BsmtHalfBath'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
df['BsmtHalfBath'].isna().sum()
# Out:
# 0

# %%
df['FullBath'].unique()
# Out:
# array([2, 1, 3, 0], dtype=int64)

# %%
df['FullBath'].isna().sum()
# Out:
# 0

# %%
df['HalfBath'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
df['HalfBath'].isna().sum()
# Out:
# 0

# %%
df['BedroomAbvGr'].unique()
# Out:
# array([2, 4, 3, 1, 5, 0, 6, 8], dtype=int64)

# %%
df['BedroomAbvGr'].isna().sum()
# Out:
# 0

# %%
df['KitchenAbvGr'].unique()
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %%
df['KitchenAbvGr'].isna().sum()
# Out:
# 0

# %%
df['KitchenQual'].unique()
# Out:
# array(['TA', 'Gd', 'Ex', 'Fa'], dtype=object)

# %%
df['KitchenQual'].isna().sum()
# Out:
# 0

# %%
df['KitchenQual'] = lab_enc.fit_transform(df['KitchenQual'])

# %%
df['TotRmsAbvGrd'].unique()
# Out:
# array([ 5,  8,  7,  9,  6, 12,  4,  2,  3, 10, 11, 14], dtype=int64)

# %%
df['TotRmsAbvGrd'].isna().sum()
# Out:
# 0

# %%
df['Functional'].unique()
# Out:
# array(['Typ', 'Mod', 'Maj1', 'Min1', 'Min2', 'Sev', 'Maj2'], dtype=object)

# %%
df['Functional'].isna().sum()
# Out:
# 0

# %%
df['Functional'] = lab_enc.fit_transform(df['Functional'])

# %%
df['Fireplaces'].unique()
# Out:
# array([1, 0, 2, 3], dtype=int64)

# %%
df['Fireplaces'].isna().sum()
# Out:
# 0

# %%
df['FireplaceQu'].unique()
# Out:
# array(['TA', 'Gd', nan, 'Fa', 'Ex', 'Po'], dtype=object)

# %%
df['FireplaceQu'].isna().sum()
# Out:
# 551

# %%
df['FireplaceQu'].mode()
# Out:
# 0    Gd
# Name: FireplaceQu, dtype: object

# %%
df['FireplaceQu'] = df['FireplaceQu'].replace(np.nan,'Gd')

# %%
df['FireplaceQu'].isna().sum()
# Out:
# 0

# %%
df['FireplaceQu'] = lab_enc.fit_transform(df['FireplaceQu'])

# %%
df['GarageType'].unique()
# Out:
# array(['Attchd', 'BuiltIn', 'Detchd', 'Basment', nan, '2Types', 'CarPort'],
#       dtype=object)

# %%
df['GarageType'].isna().sum()
# Out:
# 64

# %%
df['GarageType'].mode()
# Out:
# 0    Attchd
# Name: GarageType, dtype: object

# %%
df['GarageType'] = df['GarageType'].replace(np.nan,'Attchd')

# %%
df['GarageType'].isna().sum()
# Out:
# 0

# %%
df['GarageType'] = lab_enc.fit_transform(df['GarageType'])

# %%
df['GarageYrBlt'].unique()
# Out:
# array([1977., 1970., 1997., 2006., 1957., 1965., 1947., 1937., 2003.,
#        1974., 1955., 1923., 2002., 2007., 1987., 2001., 1988., 1950.,
#        1961., 1953., 2010., 1922., 1939., 2005., 1991., 1979., 1975.,
#        1976., 1978., 1960., 1956., 2004., 1982., 2000., 1948.,   nan,
#        1964., 1920., 1930., 1968., 1946., 1992., 1936., 1967., 1989.,
#        1959., 1966., 1916., 1941., 1998., 1962., 1926., 1925., 1983.,
#        1999., 1969., 1985., 1993., 2008., 1971., 1980., 1945., 1995.,
#        1981., 1994., 1949., 1996., 1921., 1963., 1938., 1958., 1935.,
#        1940., 1990., 1910., 1954., 1927., 2009., 1986., 1929., 1984.,
#        1973., 1924., 1942., 1900., 1931., 1951., 1934., 1972., 1932.,
#        1928., 1918., 1908., 1933., 1906., 1914., 1952., 1915.])

# %%
df['GarageYrBlt'].isna().sum()
# Out:
# 64

# %%
df['GarageYrBlt'].mode()
# Out:
# 0    2006.0
# Name: GarageYrBlt, dtype: float64

# %%
df['GarageYrBlt'] = df['GarageYrBlt'].replace(np.nan,2006)

# %%
df['GarageYrBlt'].isna().sum()
# Out:
# 0

# %%
df['GarageFinish'].unique()
# Out:
# array(['RFn', 'Unf', 'Fin', nan], dtype=object)

# %%
df['GarageFinish'].isna().sum()
# Out:
# 64

# %%
df['GarageFinish'].mode()
# Out:
# 0    Unf
# Name: GarageFinish, dtype: object

# %%
df['GarageFinish'] = df['GarageFinish'].replace(np.nan,'Unf')

# %%
df['GarageFinish'].isna().sum()
# Out:
# 0

# %%
df['GarageFinish'] = lab_enc.fit_transform(df['GarageFinish'])

# %%
df['GarageCars'].unique()
# Out:
# array([2, 3, 1, 0, 4], dtype=int64)

# %%
df['GarageCars'].isna().sum()
# Out:
# 0

# %%
df['GarageArea'].unique()
# Out:
# array([ 440,  621,  455,  546,  529,  660,  528,  484,  461,  336,  198,
#         613,  573,  300,  180,  432,  632,  504,  564,  396,  240,  368,
#         884,  450,  576,  834,  280,  600,  672,  479,  470,  308,  252,
#         480,  380,  328,  264,  463,    0,  765,  520,  246,  756,  534,
#         327,  702,  392,  288,  451,  575,  429,  738,  312,  474,  490,
#         826,  360,  850,  514,  675,  418,  625,  390,  216,  686,  905,
#         352,  682,  530,  630,  750,  562,  499,  608,  840,  836,  486,
#         286,  627,  495,  476,  739,  442,  409,  894,  482,  570,  420,
#         615,  315,  400,  824,  800,  736,  270,  434,  294,  779,  676,
#         813,  511,  642,  588,  460,  572,  539,  462,  532,  502,  505,
#         287,  812,  667,  456,  544,  384,  483,  550,  540,  377,  810,
#         870,  648,  492,  506,  200,  508,  497,  283,  586,  574,  358,
#         466,  865,  473,  275,  912,  569,  820,  690,  720,  299,  513,
# ...

# %%
df['GarageArea'].isna().sum()
# Out:
# 0

# %%
df['GarageQual'].unique()
# Out:
# array(['TA', 'Fa', nan, 'Gd', 'Ex', 'Po'], dtype=object)

# %%
df['GarageQual'].isna().sum()
# Out:
# 64

# %%
df['GarageQual'].mode()
# Out:
# 0    TA
# Name: GarageQual, dtype: object

# %%
df['GarageQual'] = df['GarageQual'].replace(np.nan,'TA')

# %%
df['GarageQual'].isna().sum()
# Out:
# 0

# %%
df['GarageQual'] = lab_enc.fit_transform(df['GarageQual'])

# %%
df['GarageCond'].unique()
# Out:
# array(['TA', 'Fa', 'Gd', nan, 'Po', 'Ex'], dtype=object)

# %%
df['GarageCond'].isna().sum()
# Out:
# 64

# %%
df['GarageCond'].mode()
# Out:
# 0    TA
# Name: GarageCond, dtype: object

# %%
df['GarageCond'] = df['GarageCond'].replace(np.nan,'TA')

# %%
df['GarageCond'].isna().sum()
# Out:
# 0

# %%
df['GarageCond'] = lab_enc.fit_transform(df['GarageCond'])

# %%
df['PavedDrive'].unique()
# Out:
# array(['Y', 'N', 'P'], dtype=object)

# %%
df['PavedDrive'].isna().sum()
# Out:
# 0

# %%
df['PavedDrive'] = lab_enc.fit_transform(df['PavedDrive'])

# %%
df['WoodDeckSF'].unique()
# Out:
# array([  0,  81, 180, 240, 100, 158, 192,  74, 121,  96, 132, 370,  58,
#        366, 166, 113, 196, 155, 237, 120, 210, 261, 168, 270, 171, 301,
#        288, 175, 252, 184,  33, 138,  53, 208, 216, 402, 351,  70, 278,
#        305, 156, 380, 224, 315, 857, 128, 371, 140, 144, 253,  66, 114,
#        250, 574, 185, 298, 187, 364, 668, 143, 222, 149, 356,  64,  68,
#        272,  85, 355, 302, 147, 161, 325, 182,  48, 198, 268,  40, 203,
#        238, 228, 116, 112, 164, 229, 517, 232, 309, 276, 367, 186, 160,
#        392, 421, 255, 214,  36, 264, 736, 586, 212, 123, 304, 509, 169,
#        173, 105,  95, 194, 142, 353, 256, 177,  38, 125,  92, 404,  60,
#        500, 324, 344, 165, 320, 382, 245,  72,  88, 172, 328,  52, 241,
#        431, 176, 197, 234, 260, 146,  55,  98, 292, 576, 322, 148, 486,
#        314, 220, 342, 219, 154, 236, 183, 349, 199,  80,  78, 110, 409,
#        335, 104, 257, 263,  49, 418, 280,  24, 269, 188, 108, 242, 201,
# ...

# %%
df['WoodDeckSF'].isna().sum()
# Out:
# 0

# %%
df['OpenPorchSF'].unique()
# Out:
# array([205, 207, 130, 122,   0,  17,  39, 150,  30,  96, 319,  64, 120,
#         82,  24, 144,  29,  62, 166,  40,  63,  36,  78, 547, 159,  28,
#        136,  84,  45, 129,  44, 229,  25,  33,  38, 128, 240, 189,  54,
#         88,  80,  48,  42, 260, 102,  20,  73,  66,  22,  50, 124,  74,
#         72,  53,  47, 104, 116, 172, 142,  35, 140,  56, 250,  92,  52,
#         32,  21, 162,  58, 146,  12, 192, 182,  27,  60,  76, 241,  59,
#         83, 112, 213,  67, 117, 114,  70, 175, 105, 154, 156,  57,  75,
#        108, 158,  68, 236, 106,  23, 110, 135, 160, 138,  16,  46,  18,
#        137,  65, 176, 406,   4, 211, 134, 235,  55, 100, 187, 113, 274,
#         98, 204,  51, 228, 191, 170,  61,   8, 180, 312, 243, 151,  91,
#        148, 121, 123,  81, 267, 132,  26, 288,  49, 292, 238, 111, 265,
#        169, 103,  11, 291, 341, 502, 188,  90, 184,  43,  87, 133, 364,
#        195, 131, 199,  34, 155,  69, 126, 234,  94, 168, 152, 523, 282,
# ...

# %%
df['OpenPorchSF'].isna().sum()
# Out:
# 0

# %%
df['EnclosedPorch'].unique()
# Out:
# array([  0, 184, 102, 112,  96, 192, 116, 126, 145,  39, 156, 200, 120,
#        286, 244,  68,  80, 216, 137, 234, 272,  44, 105,  24,  70, 114,
#         98, 280, 100,  42, 148, 202, 294, 108, 130, 176, 154, 259,  67,
#         84, 252, 208, 293, 291, 228, 129, 138, 158, 144, 185, 136, 242,
#         40, 224, 264, 128, 177,  56,  34, 189, 268,  99, 150, 205, 301,
#        275, 196, 164, 168, 180, 194, 230,  81, 212, 239,  64, 134, 162,
#        115, 218,  36, 254,  60,  77, 248, 236, 240, 210,  52, 169, 221,
#        220, 318,  30, 160, 123,  90, 170,  50, 386, 190, 552,  91, 174,
#         54, 172], dtype=int64)

# %%
df['EnclosedPorch'].isna().sum()
# Out:
# 0

# %%
df['3SsnPorch'].unique()
# Out:
# array([  0, 245, 196, 140, 180,  96, 162, 168, 144, 290, 238, 216, 182,
#        130, 304,  23, 153, 508], dtype=int64)

# %%
df['3SsnPorch'].isna().sum()
# Out:
# 0

# %%
df['ScreenPorch'].unique()
# Out:
# array([  0, 224,  95, 265,  53, 192, 480, 128, 189, 140, 160, 410, 204,
#        155, 216, 182, 126, 116, 168, 178,  90, 185, 147, 184, 153, 266,
#        222, 271, 273,  99, 176, 288,  60, 122, 180,  80, 225, 120, 144,
#         63, 156, 165, 440, 175, 161, 145, 143, 252, 190, 142,  40, 100,
#        200, 260, 259, 154, 322, 291, 287, 197, 163, 385, 170, 198, 130],
#       dtype=int64)

# %%
df['ScreenPorch'].isna().sum()
# Out:
# 0

# %%
df['PoolArea'].unique()
# Out:
# array([  0, 555, 576, 738, 519, 480, 648, 512], dtype=int64)

# %%
df['PoolArea'].isna().sum()
# Out:
# 0

# %%
df['PoolQC'].unique()
# Out:
# array([nan, 'Ex', 'Gd', 'Fa'], dtype=object)

# %%
df['PoolQC'].isna().sum()
# Out:
# 1161

# %%
df['PoolQC'].mode()
# Out:
# 0    Gd
# Name: PoolQC, dtype: object

# %%
df['PoolQC'] = df['PoolQC'].replace(np.nan,'Gd')

# %%
df['PoolQC'].isna().sum()
# Out:
# 0

# %%
df['PoolQC'] = lab_enc.fit_transform(df['PoolQC'])

# %%
df['Fence'].unique()
# Out:
# array([nan, 'MnPrv', 'GdPrv', 'GdWo', 'MnWw'], dtype=object)

# %%
df['Fence'].isna().sum()
# Out:
# 931

# %%
df['Fence'].mode()
# Out:
# 0    MnPrv
# Name: Fence, dtype: object

# %%
df['Fence'] = df['Fence'].replace(np.nan,'MnPrv')

# %%
df['Fence'].isna().sum()
# Out:
# 0

# %%
df['Fence'] = lab_enc.fit_transform(df['Fence'])

# %%
df['MiscFeature'].unique()
# Out:
# array([nan, 'Shed', 'Gar2', 'TenC', 'Othr'], dtype=object)

# %%
df['MiscFeature'].isna().sum()
# Out:
# 1124

# %%
df['MiscFeature'].mode()
# Out:
# 0    Shed
# Name: MiscFeature, dtype: object

# %%
df['MiscFeature'] = df['MiscFeature'].replace(np.nan,'Shed')

# %%
df['MiscFeature'].isna().sum()
# Out:
# 0

# %%
df['MiscFeature'].unique()
# Out:
# array(['Shed', 'Gar2', 'TenC', 'Othr'], dtype=object)

# %%
df['MiscFeature'] = lab_enc.fit_transform(df['MiscFeature'])

# %%
df['MiscVal'].unique()
# Out:
# array([    0,   400,  8300,   600,  1150,   500,  1200,   480,  1300,
#         1400,  2000,   700,   620, 15500,   450,   800,    54,   350,
#          560,  2500], dtype=int64)

# %%
df['MiscVal'].isna().sum()
# Out:
# 0

# %%
df['MoSold'].unique()
# Out:
# array([ 2, 10,  6,  1, 11,  5,  4,  7,  8,  3,  9, 12], dtype=int64)

# %%
df['MoSold'].isna().sum()
# Out:
# 0

# %%
df['YrSold'].unique()
# Out:
# array([2007, 2010, 2009, 2006, 2008], dtype=int64)

# %%
df['YrSold'].isna().sum()
# Out:
# 0

# %%
df['SaleType'].unique()
# Out:
# array(['WD', 'COD', 'New', 'ConLI', 'ConLw', 'Con', 'ConLD', 'Oth', 'CWD'],
#       dtype=object)

# %%
df['SaleType'].isna().sum()
# Out:
# 0

# %%
df['SaleType'] = lab_enc.fit_transform(df['SaleType'])

# %%
df['SaleCondition'].unique()
# Out:
# array(['Normal', 'Partial', 'Abnorml', 'Family', 'Alloca', 'AdjLand'],
#       dtype=object)

# %%
df['SaleCondition'].isna().sum()
# Out:
# 0

# %%
df['SaleCondition'] = lab_enc.fit_transform(df['SaleCondition'])

# %%
df['SalePrice'].unique()
# Out:
# array([128000, 268000, 269790, 190000, 215000, 219210, 121500, 155000,
#        140000, 118500, 119500, 237000, 201000, 126500, 135500, 165000,
#        120500, 194500, 148000, 106000, 231500, 133000, 142125, 136500,
#        146000, 217000, 112000, 394432, 113000, 188700, 319900, 135000,
#        128500, 169000, 122000, 152000, 243000, 156000,  79500, 132000,
#        144152, 130000, 149900, 124500, 179000, 147000,  39300, 312500,
#        256000,  60000, 153000,  84900, 230000, 180000, 106500, 239000,
#        107500, 123000, 176000, 228500, 117500, 350000, 200624, 173000,
#        225000,  84500, 174900,  79000, 297000,  87000, 465000, 204900,
#        127000, 159000, 170000, 159500, 102000, 109500, 163990, 189950,
#        119000, 157500, 287000, 144000, 286000, 172000, 212000, 124000,
#        150000, 205950, 251000, 129000, 223500, 475000, 335000, 115000,
#        205000, 209500, 176432, 171000, 302000, 259500, 141000, 187500,
# ...

# %%
df['SalePrice'].isna().sum()
# Out:
# 0

# %%
# all nulls filled and encoding completed,
# again check for nulls

# %%
df.isna().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
# no nulls are showing

# %%
# have a look on dataset after encoding

# %%
df
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     127         120         3       70.988     4928       1      0
# 1     889          20         3       95.000    15865       1      0
# 2     793          60         3       92.000     9920       1      0
# 3     110          20         3      105.000    11751       1      0
# 4     422          20         3       70.988    16635       1      0
# ...   ...         ...       ...          ...      ...     ...    ...
# 1163  289          20         3       70.988     9819       1      0
# 1164  554          20         3       67.000     8777       1      0
# 1165  196         160         3       24.000     2280       1      0
# 1166   31          70         0       50.000     8500       1      1
# 1167  617          60         3       70.988     7861       1      0
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
# import library for visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# distribution plot

# %%
plt.figure(figsize=(20,15),facecolor='yellow')
plotnumber=1

for column in df:
    if plotnumber<=81:
        ax = plt.subplot(17,5,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=15)
        
    plotnumber+=1
    
plt.show()

# %%
# some data left skewed and some data right skewed

# %%
# boxplot

# %%
plt.figure(figsize=(20,15),facecolor='yellow')
plotnumber=1

for column in df:
    if plotnumber<=81:
        ax = plt.subplot(17,5,plotnumber)
        plt.boxplot(df[column])
        plt.xlabel(column,fontsize=15)
        
    plotnumber+=1
    
plt.show()

# %%
# some columns are showing outliers
# now, we will check for outliers individually

# %%
# for dealing with outliers, take out quantiles and inter quantile range

# %%
q1 = df.quantile(0.25)


q3 = df.quantile(0.75)


iqr = q3 - q1

# %%
print(q1)
# Out:
# Id                  360.5
# MSSubClass           20.0
# MSZoning              3.0
# LotFrontage          60.0
# LotArea            7621.5
#                    ...
# MoSold                5.0
# YrSold             2007.0
# SaleType              8.0
# SaleCondition         4.0
# SalePrice        130375.0
# Name: 0.25, Length: 81, dtype: float64

# %%
print(q3)
# Out:
# Id                 1079.50
# MSSubClass           70.00
# MSZoning              3.00
# LotFrontage          79.25
# LotArea           11515.50
#                    ...
# MoSold                8.00
# YrSold             2009.00
# SaleType              8.00
# SaleCondition         4.00
# SalePrice        215000.00
# Name: 0.75, Length: 81, dtype: float64

# %%
print(iqr)
# Out:
# Id                 719.00
# MSSubClass          50.00
# MSZoning             0.00
# LotFrontage         19.25
# LotArea           3894.00
#                    ...
# MoSold               3.00
# YrSold               2.00
# SaleType             0.00
# SaleCondition        0.00
# SalePrice        84625.00
# Length: 81, dtype: float64

# %%
# rename some columns for further process

# %%
df = df.rename(columns={'1stFlrSF':'firstflrSF','2ndFlrSF':'secondflrSF','3SsnPorch':'thirdssnPorch'})

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', 'firstflrSF', 'secondflrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# now, start checking for outliers with the help of inter quantile range and quantiles

# %%
bb_high = (q3.BsmtHalfBath + (1.5 * iqr.BsmtHalfBath))
bb_high
# Out:
# 0.0

# %%
index = np.where(df['BsmtHalfBath'] > bb_high)
index
# Out:
# (array([   4,   64,   94,   98,  120,  133,  146,  156,  162,  164,  187,
#          196,  205,  219,  257,  290,  301,  313,  318,  351,  385,  401,
#          403,  408,  415,  417,  445,  459,  467,  478,  500,  518,  544,
#          560,  606,  612,  643,  657,  673,  691,  708,  714,  791,  810,
#          813,  866,  882,  888,  904,  942,  951,  952,  960,  968,  976,
#          990, 1034, 1038, 1057, 1098, 1119, 1120, 1140], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (1105, 81)

# %%
bb_low = (q1.BsmtHalfBath - (1.5 * iqr.BsmtHalfBath))
bb_low
# Out:
# 0.0

# %%
index = np.where(df['BsmtHalfBath'] < bb_low)
index
# Out:
# (array([], dtype=int64),)

# %%
fb_high = (q3.FullBath + (1.5 * iqr.FullBath))
fb_high
# Out:
# 3.5

# %%
index = np.where(df['FullBath'] > fb_high)
index
# Out:
# (array([], dtype=int64),)

# %%
fb_low = (q1.FullBath - (1.5 * iqr.FullBath))
fb_low
# Out:
# -0.5

# %%
index = np.where(df['FullBath'] < fb_low)
index
# Out:
# (array([], dtype=int64),)

# %%
hb_high = (q3.HalfBath + (1.5 * iqr.HalfBath))
hb_high
# Out:
# 2.5

# %%
index = np.where(df['HalfBath'] > hb_high)
index
# Out:
# (array([], dtype=int64),)

# %%
hb_low = (q1.HalfBath - (1.5 * iqr.HalfBath))
hb_low
# Out:
# -1.5

# %%
index = np.where(df['HalfBath'] < hb_low)
index
# Out:
# (array([], dtype=int64),)

# %%
bg_high = (q3.BedroomAbvGr + (1.5 * iqr.BedroomAbvGr))
bg_high
# Out:
# 4.5

# %%
index = np.where(df['BedroomAbvGr'] > bg_high)
index
# Out:
# (array([  50,  258,  439,  446,  486,  500,  508,  538,  566,  578,  626,
#          679,  761,  785,  821,  850,  876,  881,  899,  967, 1042, 1083],
#        dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (1083, 81)

# %%
bg_low = (q1.BedroomAbvGr - (1.5 * iqr.BedroomAbvGr))
bg_low
# Out:
# 0.5

# %%
index = np.where(df['BedroomAbvGr'] < bg_low)
index
# Out:
# (array([ 90, 114, 197, 449], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (1079, 81)

# %%
kg_high = (q3.KitchenAbvGr + (1.5 * iqr.KitchenAbvGr))
kg_high
# Out:
# 1.0

# %%
index = np.where(df['KitchenAbvGr'] > kg_high)
index
# Out:
# (array([  31,   65,   91,  119,  194,  195,  253,  269,  295,  338,  353,
#          363,  409,  453,  509,  544,  563,  571,  593,  599,  623,  677,
#          738,  753,  771,  791,  818,  831,  835,  839,  848,  864,  872,
#          880,  939,  945,  954,  974,  991, 1039, 1057, 1059, 1070],
#        dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
kg_low = (q1.KitchenAbvGr - (1.5 * iqr.KitchenAbvGr))
kg_low
# Out:
# 1.0

# %%
index = np.where(df['KitchenAbvGr'] < kg_low)
index
# Out:
# (array([], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (1036, 81)

# %%
kq_high = (q3.KitchenQual + (1.5 * iqr.KitchenQual))
kq_high
# Out:
# 4.5

# %%
index = np.where(df['KitchenQual'] > kq_high)
index
# Out:
# (array([], dtype=int64),)

# %%
kq_low = (q1.KitchenQual - (1.5 * iqr.KitchenQual))
kq_low
# Out:
# 0.5

# %%
index = np.where(df['KitchenQual'] < kq_low)
index
# Out:
# (array([  26,   29,   56,   61,   73,   91,   94,   95,  121,  128,  132,
#          147,  161,  173,  175,  198,  208,  217,  234,  267,  270,  271,
#          285,  286,  289,  302,  314,  318,  321,  327,  334,  338,  340,
#          347,  356,  357,  375,  380,  397,  434,  449,  451,  481,  501,
#          513,  522,  530,  554,  564,  591,  600,  609,  632,  639,  643,
#          666,  677,  682,  692,  703,  704,  753,  769,  773,  774,  803,
#          811,  812,  815,  823,  900,  915,  987,  995,  998,  999, 1023],
#        dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (959, 81)

# %%
tg_high = (q3.TotRmsAbvGrd + (1.5 * iqr.TotRmsAbvGrd))
tg_high
# Out:
# 10.0

# %%
index = np.where(df['TotRmsAbvGrd'] > tg_high)
index
# Out:
# (array([436, 833], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (957, 81)

# %%
tg_low = (q1.TotRmsAbvGrd - (1.5 * iqr.TotRmsAbvGrd))
tg_low
# Out:
# 2.0

# %%
index = np.where(df['TotRmsAbvGrd'] < tg_low)
index
# Out:
# (array([], dtype=int64),)

# %%
f_high = (q3.Functional + (1.5 *iqr.Functional))
f_high
# Out:
# 6.0

# %%
index = np.where(df['Functional'] > f_high)
index
# Out:
# (array([], dtype=int64),)

# %%
f_low = (q1.Functional - (1.5 * iqr.Functional))
f_low
# Out:
# 6.0

# %%
index = np.where(df['Functional'] < f_low)
index
# Out:
# (array([  5,   6,  39,  51,  54,  67,  71, 113, 145, 147, 151, 223, 242,
#         247, 264, 293, 304, 327, 358, 375, 390, 403, 408, 415, 418, 433,
#         457, 469, 488, 500, 503, 506, 507, 518, 521, 526, 532, 545, 550,
#         581, 588, 591, 592, 594, 619, 623, 627, 669, 684, 695, 701, 706,
#         730, 756, 762, 773, 806, 833, 849, 857, 880, 884, 886, 896, 909,
#         924, 927], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (890, 81)

# %%
fp_high = (q3.Fireplaces + (1.5 * iqr.Fireplaces))
fp_high
# Out:
# 2.5

# %%
index = np.where(df['Fireplaces'] > fp_high)
index
# Out:
# (array([ 82, 527], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (888, 81)

# %%
fp_low = (q1.Fireplaces - (1.5 * iqr.Fireplaces))
fp_low
# Out:
# -1.5

# %%
index = np.where(df['Fireplaces'] < fp_low)
index
# Out:
# (array([], dtype=int64),)

# %%
fq_high = (q3.FireplaceQu + (1.5 * iqr.FireplaceQu))
fq_high
# Out:
# 2.0

# %%
index = np.where(df['FireplaceQu'] > fq_high)
index
# Out:
# (array([  0,   1,   2,   3,   8,  12,  17,  28,  30,  32,  39,  48,  50,
#          52,  66,  73,  74,  80,  81,  87,  88,  89,  90,  92,  98, 109,
#         110, 117, 118, 122, 127, 128, 130, 138, 145, 146, 147, 154, 164,
#         171, 187, 190, 191, 192, 196, 197, 200, 206, 208, 210, 212, 215,
#         221, 223, 225, 228, 232, 237, 244, 247, 257, 263, 265, 283, 284,
#         290, 297, 298, 299, 302, 305, 308, 315, 318, 326, 328, 333, 337,
#         344, 347, 349, 350, 354, 355, 357, 363, 366, 370, 372, 373, 378,
#         381, 384, 400, 402, 420, 421, 429, 433, 438, 440, 450, 451, 460,
#         468, 475, 477, 478, 479, 481, 491, 492, 511, 512, 515, 518, 521,
#         524, 532, 533, 537, 539, 541, 542, 547, 551, 555, 559, 560, 566,
#         568, 572, 580, 583, 584, 587, 593, 601, 602, 608, 610, 613, 621,
#         624, 628, 634, 638, 643, 644, 647, 658, 659, 663, 666, 668, 669,
#         670, 675, 683, 684, 685, 688, 697, 701, 702, 703, 720, 724, 734,
# ...

# %%
fq_low = (q1.FireplaceQu - (1.5 * iqr.FireplaceQu))
fq_low
# Out:
# 2.0

# %%
index = np.where(df['FireplaceQu'] < fq_low)
index
# Out:
# (array([ 15,  42,  63, 148, 183, 224, 234, 294, 331, 332, 393, 422, 482,
#         520, 545, 651, 695, 754, 758, 776, 782, 806, 812, 866], dtype=int64),)

# %%
gt_high = (q3.GarageType + (1.5 * iqr.GarageType))
gt_high
# Out:
# 11.0

# %%
index = np.where(df['GarageType'] > gt_high)
index
# Out:
# (array([], dtype=int64),)

# %%
gt_low = (q1.GarageType - (1.5 * iqr.GarageType))
gt_low
# Out:
# -5.0

# %%
index = np.where(df['GarageType'] < gt_low)
index
# Out:
# (array([], dtype=int64),)

# %%
gb_high = (q3.GarageYrBlt + (1.5 * iqr.GarageYrBlt))
gb_high
# Out:
# 2064.5

# %%
index = np.where(df['GarageYrBlt'] > gb_high)
index
# Out:
# (array([], dtype=int64),)

# %%
gb_low = (q1.GarageYrBlt - (1.5 * iqr.GarageYrBlt))
gb_low
# Out:
# 1900.5

# %%
index = np.where(df['GarageYrBlt'] < gb_low)
index
# Out:
# (array([], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (888, 81)

# %%
gf_high = (q3.GarageFinish + (1.5 * iqr.GarageFinish))
gf_high
# Out:
# 3.5

# %%
index = np.where(df['GarageFinish'] > gf_high)
index
# Out:
# (array([], dtype=int64),)

# %%
gf_low = (q1.GarageFinish - (1.5 * iqr.GarageFinish))
gf_low
# Out:
# -0.5

# %%
index = np.where(df['GarageFinish'] < gf_low)
index
# Out:
# (array([], dtype=int64),)

# %%
gc_high = (q3.GarageCars + (1.5 * iqr.GarageCars))
gc_high
# Out:
# 3.5

# %%
index = np.where(df['GarageCars'] > gc_high)
index
# Out:
# (array([ 94, 739, 840], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (885, 81)

# %%
gc_low = (q1.GarageCars - (1.5 * iqr.GarageCars))
gc_low
# Out:
# -0.5

# %%
index = np.where(df['GarageCars'] < gc_low)
index
# Out:
# (array([], dtype=int64),)

# %%
ga_high = (q3.GarageArea + (1.5 * iqr.GarageArea))
ga_high
# Out:
# 933.0

# %%
index = np.where(df['GarageArea'] > ga_high)
index
# Out:
# (array([215, 262, 268, 308, 462, 658, 781, 830], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (877, 81)

# %%
ga_low = (q1.GarageArea - (1.5 * iqr.GarageArea))
ga_low
# Out:
# -19.0

# %%
index = np.where(df['GarageArea'] < ga_low)
index
# Out:
# (array([], dtype=int64),)

# %%
gq_high = (q3.GarageQual + (1.5 * iqr.GarageQual))
gq_high
# Out:
# 4.0

# %%
index = np.where(df['GarageQual'] > gq_high)
index
# Out:
# (array([], dtype=int64),)

# %%
gq_low = (q1.GarageQual - (1.5 * iqr.GarageQual))
gq_low
# Out:
# 4.0

# %%
index = np.where(df['GarageQual'] < gq_low)
index
# Out:
# (array([  5,  59,  73, 140, 158, 184, 189, 200, 213, 241, 243, 290, 309,
#         382, 402, 467, 489, 493, 497, 523, 534, 586, 609, 619, 631, 658,
#         671, 683, 702, 738, 770, 794, 826, 831, 848, 850], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (841, 81)

# %%
gc_high = (q3.GarageCond + (1.5 * iqr.GarageCond))
gc_high
# Out:
# 4.0

# %%
index = np.where(df['GarageCond'] > gc_high)
index
# Out:
# (array([], dtype=int64),)

# %%
gc_low = (q1.GarageCond - (1.5 * iqr.GarageCond))
gc_low
# Out:
# 4.0

# %%
index = np.where(df['GarageCond'] < gc_low)
index
# Out:
# (array([ 14, 120, 195, 209, 228, 328, 350, 542, 742, 778, 835, 839],
#        dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (829, 81)

# %%
pd_high = (q3.PavedDrive + (1.5 * iqr.PavedDrive))
pd_high
# Out:
# 2.0

# %%
index = np.where(df['PavedDrive'] > pd_high)
index
# Out:
# (array([], dtype=int64),)

# %%
pd_low = (q1.PavedDrive - (1.5 * iqr.PavedDrive))
pd_low
# Out:
# 2.0

# %%
index = np.where(df['PavedDrive'] < pd_low)
index
# Out:
# (array([  6,  21,  24,  26,  31,  32,  39,  42,  56,  91, 119, 127, 131,
#         133, 135, 144, 219, 231, 241, 251, 254, 259, 302, 306, 365, 371,
#         379, 381, 392, 419, 454, 459, 466, 467, 478, 506, 539, 542, 546,
#         559, 600, 656, 674, 681, 728, 743, 746, 752, 759, 760, 796, 802,
#         826], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (776, 81)

# %%
ws_high = (q3.WoodDeckSF + (1.5 * iqr.WoodDeckSF))
ws_high
# Out:
# 427.5

# %%
index = np.where(df['WoodDeckSF'] > ws_high)
index
# Out:
# (array([ 95, 103, 165, 209, 215, 328, 469, 546, 672, 748, 752], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (765, 81)

# %%
ws_low = (q1.WoodDeckSF - (1.5 * iqr.WoodDeckSF))
ws_low
# Out:
# -256.5

# %%
index = np.where(df['WoodDeckSF'] < ws_low)
index
# Out:
# (array([], dtype=int64),)

# %%
os_high = (q3.OpenPorchSF + (1.5 * iqr.OpenPorchSF))
os_high
# Out:
# 175.0

# %%
index = np.where(df['OpenPorchSF'] > os_high)
index
# Out:
# (array([  0,   1,  17,  59, 101, 133, 141, 157, 232, 238, 243, 268, 285,
#         289, 293, 296, 309, 383, 410, 443, 474, 502, 526, 572, 707, 719,
#         739], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (738, 81)

# %%
os_low = (q1.OpenPorchSF - (1.5 * iqr.OpenPorchSF))
os_low
# Out:
# -105.0

# %%
index = np.where(df['OpenPorchSF'] < os_low)
index
# Out:
# (array([], dtype=int64),)

# %%
ep_high = (q3.EnclosedPorch + (1.5 * iqr.EnclosedPorch))
ep_high
# Out:
# 0.0

# %%
index = np.where(df['EnclosedPorch'] > ep_high)
index
# Out:
# (array([  3,   8,   9,  14,  16,  17,  22,  24,  42,  45,  47,  56,  62,
#          73,  76,  77,  91,  93,  95,  99, 104, 106, 126, 136, 137, 151,
#         159, 163, 173, 183, 195, 201, 209, 213, 230, 231, 234, 239, 265,
#         268, 277, 279, 283, 306, 311, 317, 326, 331, 335, 352, 367, 389,
#         401, 414, 416, 429, 446, 470, 473, 498, 508, 521, 532, 536, 538,
#         541, 566, 568, 571, 581, 599, 603, 611, 614, 622, 632, 639, 674,
#         683, 711, 720, 729, 730], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (655, 81)

# %%
ep_low = (q1.EnclosedPorch - (1.5 * iqr.EnclosedPorch))
ep_low
# Out:
# 0.0

# %%
index = np.where(df['EnclosedPorch'] < ep_low)
index
# Out:
# (array([], dtype=int64),)

# %%
sp_high = (q3.ScreenPorch + (1.5 * iqr.ScreenPorch))
sp_high
# Out:
# 0.0

# %%
index = np.where(df['ScreenPorch'] >sp_high)
index
# Out:
# (array([  6,  16,  39,  45,  47,  52,  57,  72,  77,  91,  96, 102, 111,
#         156, 164, 166, 186, 189, 191, 198, 216, 219, 223, 229, 233, 243,
#         250, 251, 256, 285, 287, 294, 328, 329, 330, 351, 367, 404, 418,
#         440, 463, 470, 483, 490, 493, 508, 511, 537, 565, 588, 607, 631,
#         650], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (602, 81)

# %%
sp_low = (q1.ScreenPorch - (1.5 * iqr.ScreenPorch))
sp_low
# Out:
# 0.0

# %%
index = np.where(df['ScreenPorch'] < sp_low)
index
# Out:
# (array([], dtype=int64),)

# %%
pa_high = (q3.PoolArea + (1.5 * iqr.PoolArea))
pa_high
# Out:
# 0.0

# %%
index = np.where(df['PoolArea'] > pa_high)
index
# Out:
# (array([ 97, 464], dtype=int64),)

# %%
pa_low = (q1.PoolArea - (1.5 * iqr.PoolArea))
pa_low
# Out:
# 0.0

# %%
index = np.where(df['PoolArea'] < pa_low)
index
# Out:
# (array([], dtype=int64),)

# %%
pq_high = (q3.PoolQC + (1.5 * iqr.PoolQC))
pq_high
# Out:
# 2.0

# %%
index = np.where(df['PoolQC'] > pq_high)
index
# Out:
# (array([], dtype=int64),)

# %%
pq_low = (q1.PoolQC - (1.5 * iqr.PoolQC))
pq_low
# Out:
# 2.0

# %%
index = np.where(df['PoolQC'] < pq_low)
index
# Out:
# (array([464], dtype=int64),)

# %%
f_high = (q3.Fence + (1.5 * iqr.Fence))
f_high
# Out:
# 2.0

# %%
index = np.where(df['Fence'] > f_high)
index
# Out:
# (array([ 27,  72, 204, 431, 433], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (597, 81)

# %%
f_low = (q1.Fence - (1.5 * iqr.Fence))
f_low
# Out:
# 2.0

# %%
index = np.where(df['Fence'] < f_low)
index
# Out:
# (array([ 19,  30,  48,  56,  68,  71,  74,  83,  92,  95, 100, 128, 143,
#         149, 160, 164, 168, 169, 185, 187, 203, 207, 212, 216, 222, 232,
#         284, 288, 302, 305, 313, 319, 325, 326, 329, 363, 380, 412, 424,
#         426, 459, 512, 515, 550, 571, 584], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (551, 81)

# %%
mf_high = (q3.MiscFeature + (1.5 * iqr.MiscFeature))
mf_high
# Out:
# 2.0

# %%
index = np.where(df['MiscFeature'] > mf_high)
index
# Out:
# (array([], dtype=int64),)

# %%
mf_low = (q1.MiscFeature - (1.5 * iqr.MiscFeature))
mf_low
# Out:
# 2.0

# %%
index = np.where(df['MiscFeature'] < mf_low)
index
# Out:
# (array([241, 430], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (549, 81)

# %%
mv_high = (q3.MiscVal + (1.5 * iqr.MiscVal))
mv_high
# Out:
# 0.0

# %%
index = np.where(df['MiscVal'] > mv_high)
index
# Out:
# (array([ 45,  59,  92, 113, 200, 232, 301, 333, 404, 422, 514], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (538, 81)

# %%
mv_low = (q1.MiscVal - (1.5 * iqr.MiscVal))
mv_low
# Out:
# 0.0

# %%
index = np.where(df['MiscVal'] < mv_low)
index
# Out:
# (array([], dtype=int64),)

# %%
ms_high = (q3.MoSold + (1.5 * iqr.MoSold))
ms_high
# Out:
# 12.5

# %%
index = np.where(df['MoSold'] > ms_high)
index
# Out:
# (array([], dtype=int64),)

# %%
ms_low = (q1.MoSold - (1.5 * iqr.MoSold))
ms_low
# Out:
# 0.5

# %%
index = np.where(df['MoSold'] < ms_low)
index
# Out:
# (array([], dtype=int64),)

# %%
ys_high = (q3.YrSold + (1.5 * iqr.YrSold))
ys_high
# Out:
# 2012.0

# %%
index = np.where(df['YrSold'] > ys_high)
index
# Out:
# (array([], dtype=int64),)

# %%
ys_low = (q1.YrSold - (1.5 * iqr.YrSold))
ys_low
# Out:
# 2004.0

# %%
index = np.where(df['YrSold'] < ys_low)
index
# Out:
# (array([], dtype=int64),)

# %%
st_high = (q3.SaleType + (1.5 * iqr.SaleType))
st_high
# Out:
# 8.0

# %%
index = np.where(df['SaleType'] > st_high)
index
# Out:
# (array([], dtype=int64),)

# %%
st_low = (q1.SaleType - (1.5 * iqr.SaleType))
st_low
# Out:
# 8.0

# %%
index = np.where(df['SaleType'] < st_low)
index
# Out:
# (array([  1,   2,   5,  30,  33,  38,  40,  43,  71,  75,  83,  85,  87,
#          93,  97, 102, 108, 109, 114, 124, 138, 145, 148, 154, 155, 156,
#         159, 164, 165, 170, 174, 181, 188, 191, 193, 201, 205, 219, 223,
#         229, 249, 251, 256, 259, 261, 265, 277, 298, 302, 303, 311, 312,
#         319, 327, 334, 339, 344, 345, 346, 347, 349, 351, 353, 354, 359,
#         365, 373, 384, 392, 395, 397, 414, 430, 435, 442, 444, 445, 456,
#         470, 475, 477, 485, 486, 488, 496, 497, 498, 502, 509, 528, 531],
#        dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (447, 81)

# %%
sc_high = (q3.SaleCondition + (1.5 * iqr.SaleCondition))
sc_high
# Out:
# 4.0

# %%
index = np.where(df['SaleCondition'] > sc_high)
index
# Out:
# (array([], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (447, 81)

# %%
sc_low = (q1.SaleCondition - (1.5 * iqr.SaleCondition))
sc_low
# Out:
# 4.0

# %%
index = np.where(df['SaleCondition'] < sc_low)
index
# Out:
# (array([ 11,  12,  19,  22,  45,  82,  87,  98,  99, 106, 114, 138, 152,
#         162, 172, 180, 193, 208, 232, 237, 252, 255, 275, 281, 301, 309,
#         312, 333, 379, 386, 438, 439], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (415, 81)

# %%
# a lot of outliers removed from dataset

# %%
# when we started checking outliers, 1168 rows are present in dataset, but after removing outliers only 415 rows left

# %%
# again, distribution plot to check the trend of dataset

# %%
plt.figure(figsize=(20,15),facecolor='yellow')
plotnumber=1

for column in df:
    if plotnumber<=81:
        ax = plt.subplot(17,5,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=15)
        
    plotnumber+=1
    
plt.show()

# %%
# now it look some better than first distribution plot

# %%
# again boxplot

# %%
plt.figure(figsize=(20,15),facecolor='yellow')
plotnumber=1

for column in df:
    if plotnumber<=81:
        ax = plt.subplot(17,5,plotnumber)
        plt.boxplot(df[column])
        plt.xlabel(column,fontsize=15)
        
    plotnumber+=1
    
plt.show()

# %%
# also some outliers are showing, but according to process, tried my best to remove outliers

# %%
# heatmap

# %%
corr = df.corr().abs()

plt.figure(figsize=(40,30))
sns.heatmap(corr, annot=True)


plt.show()

# %%
# two columns are showing high relation in between

# %%
# plot scatter to check their relation

# %%
plt.scatter(df.GarageCars,df.GarageArea)

plt.xlabel('GarageArea')
plt.ylabel('GarageCars')

plt.show()

# %%
# a good relation is also shown by scatter plot

# %%
# let's delete one of them

# %%
df = df.drop(columns='GarageArea')

# %%
df.shape
# Out:
# (415, 80)

# %%
df
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 2      793          60         3       92.000     9920       1      0
# 11     833          60         3       44.000     9548       1      0
# 12     277          20         3      129.000     9196       1      0
# 17     728          20         3       64.000     7314       1      0
# 19    1105         160         4       24.000     2016       1      0
# ...    ...         ...       ...          ...      ...     ...    ...
# 1158   673          20         3       70.988    11250       1      0
# 1161  1301          60         3       70.988    10762       1      0
# 1163   289          20         3       70.988     9819       1      0
# 1165   196         160         3       24.000     2280       1      0
# 1167   617          60         3       70.988     7861       1      0
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
# split data into two variables for further process

# %%
x = df.drop(columns='SalePrice')

y = df['SalePrice']

# %%
# Standard scaler for standardize the data and train test split

# %%
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split

# %%
# standardize the data

# %%
scaler = StandardScaler()

x_scaled = scaler.fit_transform(x)

# %%
# train test split

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.25,random_state=100)

# %%
# library for checking the error of model

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
# because our target variable present as continous data so we apply here regression algorithm

# %%
# first model Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr_pred = lr.predict(x_test)

# %%
lr.score(x_train,y_train)
# Out:
# 0.9215940341884523

# %%
lr.score(x_test,y_test)
# Out:
# 0.9143264775649109

# %%
accuracy = r2_score(y_test,lr_pred)

accuracy
# Out:
# 0.9143264775649109

# %%
mean_absolute_error(y_test,lr_pred)
# Out:
# 13590.516293593866

# %%
mean_squared_error(y_test,lr_pred)
# Out:
# 301455598.2529582

# %%
plt.scatter(y_test,lr_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')

plt.show()

# %%
# by scatter plot, a trend is shown 
# if we draw a line in the middle passing through all datapoints, all datapoints comes very close to line

# %%
# Regularisaton

# %%
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV

# %%
lassocv = LassoCV(alphas=None,max_iter=100,normalize=True)

# %%
lassocv.fit(x_train,y_train)
# Out:
# LassoCV(max_iter=100, normalize=True)

# %%
alpha = lassocv.alpha_

# %%
lasso_reg = Lasso(alpha)

# %%
lasso_reg.fit(x_train,y_train)
# Out:
# Lasso(alpha=136.95579347371563)

# %%
lasso_reg.score(x_train,y_train)
# Out:
# 0.9207170834555928

# %%
lasso_reg.score(x_test,y_test)
# Out:
# 0.9179629499449213

# %%
ridgecv = RidgeCV(alphas=np.arange(0.001,0.1,0.01),normalize=True)

# %%
ridgecv.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]),
#         normalize=True)

# %%
alpha = ridgecv.alpha_

# %%
ridge_reg = Ridge(alpha)

# %%
ridge_reg.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.09099999999999998)

# %%
ridge_reg.score(x_train,y_train)
# Out:
# 0.9216008410134138

# %%
ridge_reg.score(x_test,y_test)
# Out:
# 0.9143088855561461

# %%
# second model Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor()

dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt_pred = dt.predict(x_test)

# %%
dt.score(x_train,y_train)
# Out:
# 1.0

# %%
dt.score(x_test,y_test)
# Out:
# 0.7052274209052093

# %%
accuracy = r2_score(y_test,dt_pred)

accuracy
# Out:
# 0.7052274209052093

# %%
mean_absolute_error(y_test,dt_pred)
# Out:
# 24123.865384615383

# %%
mean_squared_error(y_test,dt_pred)
# Out:
# 1037203113.0961539

# %%
rmse = np.sqrt(840596745)

# %%
rmse
# Out:
# 28993.046493944028

# %%
plt.scatter(y_test,dt_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')

plt.show()

# %%
# according to scatter plot, a very little datapoints comes in range of line if we draw through middle of datapoints

# %%
# third model RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf_pred = rf.predict(x_test)

# %%
rf.score(x_train,y_train)
# Out:
# 0.9685268063852024

# %%
rf.score(x_test,y_test)
# Out:
# 0.8934867699034065

# %%
accuracy = r2_score(y_test,rf_pred)

accuracy
# Out:
# 0.8934867699034065

# %%
mean_absolute_error(y_test,rf_pred)
# Out:
# 14913.01798076923

# %%
mean_squared_error(y_test,rf_pred)
# Out:
# 374783347.15315473

# %%
rmse = np.sqrt(342832390)

# %%
rmse
# Out:
# 18515.733579850406

# %%
plt.scatter(y_test,rf_pred)

plt.xlabel('Actual')
plt.ylabel('Predicted')

plt.show()

# %%
# in this plot seems like some datapoints comes in range of line if we draw through middle of datapoints

# %%
# fourth model SVM

# %%
from sklearn.svm import SVR

# %%
svr = SVR()

svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
svr_pred = svr.predict(x_test)

# %%
svr.score(x_train,y_train)
# Out:
# -0.005127579464706322

# %%
svr.score(x_test,y_test)
# Out:
# -0.014506241074283555

# %%
accuracy = r2_score(y_test,svr_pred)
accuracy
# Out:
# -0.014506241074283555

# %%
# fifth model AdaBoost

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
ada = AdaBoostRegressor()

ada.fit(x_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
ada_pred = ada.predict(x_test)

# %%
ada.score(x_train,y_train)
# Out:
# 0.9149565434336266

# %%
ada.score(x_test,y_test)
# Out:
# 0.8558417351951896

# %%
accuracy = r2_score(y_test,ada_pred)
accuracy
# Out:
# 0.8558417351951896

# %%
mean_absolute_error(y_test,ada_pred)
# Out:
# 17614.93351189562

# %%
mean_squared_error(y_test,ada_pred)
# Out:
# 507243250.0107384

# %%
rmse = np.sqrt(497194180)

# %%
rmse
# Out:
# 22297.851466004522

# %%
plt.scatter(y_test,ada_pred)

plt.xlabel('Actual')
plt.ylabel('Predicted')

plt.show()

# %%
# some datapoints comes in range of line if we draw in middle od datapoints

# %%
# hyperparameter tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
params = {'n_estimators':[20,30,40,50],'learning_rate':[0.20,0.25,0.30,0.35]}

# %%
rnd_srch = RandomizedSearchCV(AdaBoostRegressor(),cv=5,param_distributions=params)

# %%
rnd_srch.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=AdaBoostRegressor(),
#                    param_distributions={'learning_rate': [0.2, 0.25, 0.3, 0.35],
#                                         'n_estimators': [20, 30, 40, 50]})

# %%
rnd_srch.best_estimator_
# Out:
# AdaBoostRegressor(learning_rate=0.2)

# %%
ada1 = AdaBoostRegressor(learning_rate=0.3)

ada1.fit(x_train,y_train)
# Out:
# AdaBoostRegressor(learning_rate=0.3)

# %%
ada1_pred = ada1.predict(x_test)

# %%
ada1.score(x_train,y_train)
# Out:
# 0.9085975762895622

# %%
ada1.score(x_test,y_test)
# Out:
# 0.8533984748141226

# %%
accuracy = r2_score(y_test,ada1_pred)
accuracy
# Out:
# 0.8533984748141226

# %%
# after hyperparameter tuning adaboost is giving likely same result so consider it and save the model

# %%
import pickle

# %%
pickle.dump(ada1,open('ada1_PHousing','wb'))
